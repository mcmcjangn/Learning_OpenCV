# %%
import cv2
import numpy as np

src=cv2.imread('./data/lena.jpg',0)
print(src.shape)

dst=cv2.resize(src,dsize=(320,240))
dst2=cv2.resize(src,dsize=(0,0),fx=1.5,fy=1.2)

cv2.imshow('dst',dst)
cv2.imshow('dst2',dst2)
cv2.waitKey()
cv2.destroyAllWindows()

# 3번째 상자
src=cv2.imread('./data/lena.jpg')

dst1=cv2.rotate(src,cv2.ROTATE_90_CLOCKWISE)
dst2=cv2.rotate(src,cv2.ROTATE_90_COUNTERCLOCKWISE)

cv2.imshow('dst',dst)
cv2.imshow('dst2',dst2)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread('./data/lena.jpg')

rows, cols, channels = src.shape
M1 = cv2.getRotationMatrix2D((rows/2, cols/2), 45, 0.5)
M2 = cv2.getRotationMatrix2D((rows/2, cols/2), -45, 1.0)

dst1 = cv2.warpAffine(src, M1, (rows, cols))
dst2 = cv2.warpAffine(src, M2, (rows, cols))

cv2.imshow('dst1', dst1)
cv2.imshow('dst2', dst2)
cv2.waitKey ()
cv2.destroyAllWindows ()

# %%
# pip install imutils
import cv2
import imutils

src = cv2. imread('./data/lena.jpg')
rows, cols, channels = src.shape
dst1 = imutils.translate(src, 10, 30)
dst2 = imutils.rotate(src, angle=10, center=(rows/2, cols/2))
dst3 = imutils.resize(src, width=1000, height=1000)

cv2.imshow('dst1', dst1)
cv2.imshow('dst2', dst2)
cv2.imshow( 'dst3', dst3)

cv2.waitKey ()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

src = cv2.imread('./data/lena.jpg')

rows, cols, channels = src.shape

print(src.shape)
usangle = 0
scales =1

#TODO: 변수 선언


while True:   
    key = cv2.waitKeyEx(30)
    #TODO: 키 입력 별 처리||

    if key == 27:  #ESC 
        cv2.destroyAllWindows()
        break
    elif key == 0x250000: # left
        #TODO
        usangle += 10
    elif key == 0x270000: # right
        #TODO
        usangle -= 10
        
    elif key == 0x280000: # down
        #TODO
        scales -= .05 
        
    elif key == 0x260000: # up
        #TODO
        scales += .05
        
    #TODO: 변환 처리 및 이미지 출력
    M1 = cv2.getRotationMatrix2D((rows/2, cols/2), usangle, scales)
    dst1 = cv2.warpAffine(src, M1, (rows, cols))
    cv2.imshow('1', dst1)

# %%
import cv2
import numpy as np
src1 = cv2.imread('./data/lena.jpg', cv2.IMREAD_GRAYSCALE)
src2 = np.zeros(shape=(512,512), dtype=np.uint8) + 100

dst1 = src1 + src2
dst2 = cv2.add(src1, src2)
#add 하는 것이 좋다. 
#dst2 = cv2.add(src1, sr2, dtpe = cv2.CV_8U)

cv2.imshow('dst1', dst1)
cv2.imshow('dst2', dst2)
cv2.waitKey ()
cv2.destroyAllWindows ()

# %%
import cv2
import numpy as np

src1 = cv2.imread('./data/lena.jpg')
src2 = cv2.imread('./data/baboon.jpg')

dst1 = cv2.addWeighted(src1, 0.2, src2, 0.8, 0)
cv2.imshow('dst1', dst1)
cv2.waitKey ()
cv2.destroyAllWindows ()

# %%
import cv2
import numpy as np

src2 = cv2.imread('./data/opencv_logo.png')
gray = cv2.cvtColor(src2,cv2.COLOR_BGR2GRAY)
ret,mask=cv2.threshold(gray, 160,255,cv2.THRESH_BINARY)
cv2.imshow('mask', mask)
cv2.waitKey ()
cv2.destroyAllWindows ()

# %%
import cv2
import numpy as np

src1 = cv2. imread('./data/lena.jpg')
src2 = cv2. imread('./data/opencv_logo.png')
rows, cols, channels = src2.shape
roi=src1[0:rows,0:cols] #sr1에서 sr2의 row와 col의 크기를 roi로

gray=cv2.cvtColor(src2,cv2.COLOR_BGR2GRAY)
#gray 이미지에서 160보다 작은 부분은 모두 까맣게 칠함
ret,mask=cv2.threshold(gray, 160,255,cv2.THRESH_BINARY)
#로고 부분이 1이었는데0이 되면서 로고부분이 흰색이 됨
mask_inv=cv2.bitwise_not(mask)
#똑같은 대상을 and연산 (roi, roi)
#뒤에 따라오는 mask = mask 의 뜻은 흰색 영역.
#따라서 흰 부분인 바깥 영역만 and 연산함
#src1_bg에는 lena 이미지에서 로고 부분만 비어있음
src1_bg=cv2.bitwise_and(roi,roi,mask=mask)
#mask_inv 로고 부분이 흰색
#로고부분만 채워져 있고 나머지는 비어있음
src2_fg=cv2.bitwise_and(src2,src2,mask=mask_inv)
#둘이 합칠 땐 or 연산
dst=cv2.bitwise_or(src1_bg,src2_fg)

cv2. imshow('gray', gray)
cv2. imshow('mask', mask)
cv2. imshow('mask_inv', mask_inv)
cv2. imshow('src1_bg', src1_bg)
cv2. imshow('src2_fg', src2_fg)
cv2. imshow('dst', dst)

cv2. waitKey ()
cv2. destroyAllWindows()

# %%
import cv2
import numpy as np

src1 = cv2.imread('./data/lena.jpg', cv2.IMREAD_GRAYSCALE)
src2 = np.zeros(shape=(512, 512), dtype=np.uint8) + 255

# src1에서 255는 0이되고 0은 255가 됨
dst1 = 255 - src1  # inverse

dst2 = cv2.subtract(src2, src1)
#두개가 같으면 1 다르면 0
dst3 = cv2.compare(dst1, dst2, cv2.CMP_EQ)  # CV2. CMP_EQ
#dst3에서 0이 아닌게 몇 개인지 출력함 -> 512*512 = 262144 -> 둘이 똑같은 이미지다.
n = cv2.countNonZero(dst3)
print('n=', n)

cv2.imshow('src1', src1)
cv2.imshow('dst1', dst1)
cv2.imshow('dst2', dst2)
cv2.imshow('dst3', dst3)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# n= 262144
